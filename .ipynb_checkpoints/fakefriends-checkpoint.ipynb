# %%
import pandas as pd

# %%
fakefriendsdf = pd.read_csv("fakefriends.csv", names=["name", "age", "numFriends"], index_col=0)

# %%
fakefriendsdf = fakefriendsdf.sort_values(by=['age'])

# %%
fakefriendsdf
# Out:
#          name  age  numFriends
# 377   Beverly   18         418
# 439      Data   18         417
# 444     Keiko   18         472
# 115     Dukat   18         397
# 404    Kasidy   18          24
# 494    Kasidy   18         194
# 106   Beverly   18         499
# 341      Data   18         326
# 225      Elim   19         106
# 366     Keiko   19         119
# 21      Miles   19         268
# 133     Quark   19         265
# 54      Brunt   19           5
# 136      Will   19         335
# 409       Nog   19         267
# 492     Dukat   19          36
# 304      Will   19         404
# 52    Beverly   19         269
# 373     Quark   19         272
# 48        Nog   20           1
# 327    Julian   20          63
# 349    Kasidy   20         277
# 60     Geordi   20         100
# 73      Brunt   20         384
# 403    Weyoun   21         224
# 25        Ben   21         445
# 66     Geordi   21         477
# 244     Dukat   21         471
# 281      Worf   21          89
# ...

# %%
fakefriendsdf.to_csv("fakefriendsordered.csv")
